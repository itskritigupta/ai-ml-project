# %%
# !pip install matplotlib
# !pip install sklearn
# !pip install seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (3.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib) (21.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: numpy>=1.17 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib) (1.21.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: setuptools-scm>=4 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib) (6.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib) (4.28.1)
# Requirement already satisfied: six>=1.5 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from setuptools-scm>=4->matplotlib) (58.0.4)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from setuptools-scm>=4->matplotlib) (1.2.2)
# Requirement already satisfied: sklearn in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from sklearn) (1.0.1)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from scikit-learn->sklearn) (1.21.2)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from scikit-learn->sklearn) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from scikit-learn->sklearn) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: seaborn in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: scipy>=1.0 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from seaborn) (1.21.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from seaborn) (3.5.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: setuptools-scm>=4 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib>=2.2->seaborn) (6.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib>=2.2->seaborn) (4.28.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from matplotlib>=2.2->seaborn) (21.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (58.0.4)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\oshin gupta\.conda\envs\kriti\lib\site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (1.2.2)

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import seaborn as sns
sns.set(style='white')
sns.set(style='whitegrid',color_codes=True)

# %%
df = pd.read_csv("C:\\Users\OSHING~1\Downloads\Admission_Predict_Ver1.1.csv")

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# 25%      3.00000    8.127500    0.000000           0.63000
# 50%      3.50000    8.560000    1.000000           0.72000
# 75%      4.00000    9.040000    1.000000           0.82000
# max      5.00000    9.920000    1.000000           0.97000

# %%
df.rename(columns = {'Chance of Admit ':'Chance of Admit', 'LOR ':'LOR'}, inplace=True)
df.drop(labels='Serial No.', axis=1, inplace=True)

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
sns.distplot(df['CGPA'])
plt.title('CGPA Distribution of Applicants')

plt.subplot(1,2,2)
sns.regplot(df['CGPA'], df['Chance of Admit'])
plt.title('CGPA vs Chance of Admit')
# Out:
# C:\Users\Oshin Gupta\.conda\envs\kriti\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Oshin Gupta\.conda\envs\kriti\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'CGPA vs Chance of Admit')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
sns.distplot(df['GRE Score'])
plt.title('Distributed GRE Scores of Applicants')

plt.subplot(1,2,2)
sns.regplot(df['GRE Score'], df['Chance of Admit'])
plt.title('GRE Scores vs Chance of Admit')
# Out:
# C:\Users\Oshin Gupta\.conda\envs\kriti\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Oshin Gupta\.conda\envs\kriti\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'GRE Scores vs Chance of Admit')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
sns.distplot(df['TOEFL Score'])
plt.title('Distributed TOEFL Scores of Applicants')

plt.subplot(1,2,2)
sns.regplot(df['TOEFL Score'], df['Chance of Admit'])
plt.title('TOEFL Scores vs Chance of Admit')
# Out:
# C:\Users\Oshin Gupta\.conda\envs\kriti\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Oshin Gupta\.conda\envs\kriti\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'TOEFL Scores vs Chance of Admit')

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.countplot(df['Research'])
plt.title('Research Experience')
plt.ylabel('Number of Applicants')
ax.set_xticklabels(['No Research Experience', 'Has Research Experience'])
# Out:
# C:\Users\Oshin Gupta\.conda\envs\kriti\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'No Research Experience'), Text(1, 0, 'Has Research Experience')]

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.countplot(df['University Rating'])
plt.title('University Rating')
plt.ylabel('Number of Applicants')
# Out:
# C:\Users\Oshin Gupta\.conda\envs\kriti\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Number of Applicants')

# %%
targets = df['Chance of Admit']
features = df.drop(columns = {'Chance of Admit'})

X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
forest = RandomForestRegressor(n_estimators=110,max_depth=6,random_state=0)
forest.fit(X_train, y_train)
y_predict = forest.predict(X_test)
forest_score = (forest.score(X_test, y_test))*100
forest_score
# Out:
# 79.75303947372548
